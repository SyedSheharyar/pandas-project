# %%
import pandas as pd
import numpy as empty

# %%
netflix = pd.read_csv("netflix.csv")

# %%
netflix
# Out:
#          type                                 title  date_added release_year  \
# 0       Movie              **Dick Johnson Is Dead**   9/25/2021        2020)
# 1     TV Show                         **Ganglands**   9/24/2021        2021C
# 2     TV Show                     **Midnight Mass**   9/24/2021        2021c
# 3       Movie  **Confessions of an Invisible Girl**   9/22/2021         2021
# 4       Movie                           **Sankofa**   9/24/2021        1993S
# ...       ...                                   ...         ...          ...
# 3996    Movie                        **One 2 Ka 4**   3/15/2017        2001S
# 3997    Movie     **Jim Norton: Mouthful of Shame**   3/14/2017         2017
# 3998    Movie                        **100 Meters**  03/10/2017        2016s
# 3999    Movie                     **Burning Sands**  03/10/2017        2017s
# 4000    Movie             **The Butterfly's Dream**  03/10/2017         2013
#
# ...

# %%
netflix.columns
# Out:
# Index(['type', 'title', 'date_added', 'release_year', 'rating', 'listed_in'], dtype='object')

# %%
netflix['release_year']
# Out:
# 0       2020)
# 1       2021C
# 2       2021c
# 3        2021
# 4       1993S
#         ...
# 3996    2001S
# 3997     2017
# 3998    2016s
# 3999    2017s
# 4000     2013
# Name: release_year, Length: 4001, dtype: object

# %%
netflix.value_counts
# Out:
# <bound method DataFrame.value_counts of          type                             title  date_added release_year  \
# 0       Movie              Dick Johnson Is Dead   9-25-2021         2020
# 1     TV Show                         Ganglands   9-24-2021         2021
# 2     TV Show                     Midnight Mass   9-24-2021         2021
# 3       Movie  Confessions of an Invisible Girl   9-22-2021         2021
# 4       Movie                           Sankofa   9-24-2021         1993
# ...       ...                               ...         ...          ...
# 3996    Movie                        One 2 Ka 4   3-15-2017         2001
# 3997    Movie     Jim Norton: Mouthful of Shame   3-14-2017         2017
# 3998    Movie                        100 Meters  03-10-2017         2016
# 3999    Movie                     Burning Sands  03-10-2017         2017
# 4000    Movie             The Butterfly's Dream  03-10-2017         2013
#
#      rating                 listed_in
# ...

# %%
netflix['type'].unique()
# Out:
# array(['Movie', 'TV Show', nan], dtype=object)

# %%
netflix['type'] == 'TV Show'
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# 4000    False
# Name: type, Length: 4001, dtype: bool

# %%
netflix['type'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# 4000    False
# Name: type, Length: 4001, dtype: bool

# %%
netflix[netflix['type'].isnull()]
# Out:
#      type                              title  date_added release_year  \
# 6     NaN                   **The Starling**   9/24/2021        2021)
# 17    NaN          **Jailbirds New Orleans**   9/24/2021        2021)
# 29    NaN                          **Jeans**   9/21/2021        1998(
# 41    NaN                    **Mighty Raju**  09/09/2021        2017(
# 51    NaN                 **Minsara Kanavu**   9/21/2021        1997s
# ...   ...                                ...         ...          ...
# 3822  NaN        **What Happened to Monday**   8/18/2017        2017(
# 3823  NaN    **Brad Paisley's Comedy Rodeo**   8/15/2017         2017
# 3824  NaN  **Colin Quinn: Unconstitutional**   8/15/2017         2015
# 3825  NaN                   **The Outcasts**   8/14/2017        2017s
# 3826  NaN    **Chocolate City: Vegas Strip**  08/12/2017        2017C
#
#        rating                                         listed_in
# ...

# %%
netflix['type']  == "nan"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# 4000    False
# Name: type, Length: 4001, dtype: bool

# %%
netflix.loc[ : ,"type"]
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3         Movie
# 4         Movie
#          ...
# 3996      Movie
# 3997      Movie
# 3998      Movie
# 3999      Movie
# 4000      Movie
# Name: type, Length: 4001, dtype: object

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          3934 non-null   object
#  1   title         4001 non-null   object
#  2   date_added    4001 non-null   object
#  3   release_year  4001 non-null   object
#  4   rating        4001 non-null   object
#  5   listed_in     4001 non-null   object
# dtypes: object(6)
# memory usage: 187.7+ KB

# %%
netflix[netflix['type'].isnull()]
# Out:
#      type                              title  date_added release_year  \
# 6     NaN                   **The Starling**   9/24/2021        2021)
# 17    NaN          **Jailbirds New Orleans**   9/24/2021        2021)
# 29    NaN                          **Jeans**   9/21/2021        1998(
# 41    NaN                    **Mighty Raju**  09/09/2021        2017(
# 51    NaN                 **Minsara Kanavu**   9/21/2021        1997s
# ...   ...                                ...         ...          ...
# 3822  NaN        **What Happened to Monday**   8/18/2017        2017(
# 3823  NaN    **Brad Paisley's Comedy Rodeo**   8/15/2017         2017
# 3824  NaN  **Colin Quinn: Unconstitutional**   8/15/2017         2015
# 3825  NaN                   **The Outcasts**   8/14/2017        2017s
# 3826  NaN    **Chocolate City: Vegas Strip**  08/12/2017        2017C
#
#        rating                                         listed_in
# ...

# %%
index = netflix[netflix['type'].isnull()].index

# %%
index
# Out:
# Int64Index([   6,   17,   29,   41,   51,   52,   68,   69,   84,   97,  112,
#              126,  139,  163,  210,  244,  245,  246,  247,  248,  249,  250,
#              251,  252,  253,  254,  255,  256,  257, 2147, 2148, 2149, 2150,
#             2151, 2152, 2153, 2154, 2155, 3731, 3732, 3733, 3734, 3735, 3736,
#             3737, 3738, 3739, 3740, 3741, 3742, 3743, 3744, 3812, 3813, 3814,
#             3815, 3816, 3817, 3818, 3819, 3820, 3821, 3822, 3823, 3824, 3825,
#             3826],
#            dtype='int64')

# %%
netflix
# Out:
#          type                             title  date_added release_year  \
# 0       Movie              Dick Johnson Is Dead   9-25-2021         2020
# 1     TV Show                         Ganglands   9-24-2021         2021
# 2     TV Show                     Midnight Mass   9-24-2021         2021
# 3       Movie  Confessions of an Invisible Girl   9-22-2021         2021
# 4       Movie                           Sankofa   9-24-2021         1993
# ...       ...                               ...         ...          ...
# 3996    Movie                        One 2 Ka 4   3-15-2017         2001
# 3997    Movie     Jim Norton: Mouthful of Shame   3-14-2017         2017
# 3998    Movie                        100 Meters  03-10-2017         2016
# 3999    Movie                     Burning Sands  03-10-2017         2017
# 4000    Movie             The Butterfly's Dream  03-10-2017         2013
#
#      rating                 listed_in
# 0     PG-13             Documentaries
# ...

# %%
netflix.iloc[index,:]
# Out:
#          type                          title  date_added release_year rating  \
# 6     Unknown                   The Starling   9-24-2021         2021  PG-13
# 17    Unknown          Jailbirds New Orleans   9-24-2021         2021  TV-MA
# 29    Unknown                          Jeans   9-21-2021         1998  TV-14
# 41    Unknown                    Mighty Raju  09-09-2021         2017  TV-Y7
# 51    Unknown                 Minsara Kanavu   9-21-2021         1997  TV-PG
# ...       ...                            ...         ...          ...    ...
# 3822  Unknown        What Happened to Monday   8-18-2017         2017  TV-MA
# 3823  Unknown    Brad Paisley's Comedy Rodeo   8-15-2017         2017  TV-MA
# 3824  Unknown  Colin Quinn: Unconstitutional   8-15-2017         2015  TV-MA
# 3825  Unknown                   The Outcasts   8-14-2017         2017  TV-14
# 3826  Unknown    Chocolate City: Vegas Strip  08-12-2017         2017  TV-MA
#
#                listed_in
# ...

# %%
netflix.iloc[index, 4]
# Out:
# 6       PG-13
# 17      TV-MA
# 29      TV-14
# 41      TV-Y7
# 51      TV-PG
#         ...
# 3822    TV-MA
# 3823    TV-MA
# 3824    TV-MA
# 3825    TV-14
# 3826    TV-MA
# Name: rating, Length: 67, dtype: object

# %%
netflix.head(20)
# Out:
#        type                                 title  date_added release_year  \
# 0     Movie              **Dick Johnson Is Dead**   9/25/2021        2020)
# 1   TV Show                         **Ganglands**   9/24/2021        2021C
# 2   TV Show                     **Midnight Mass**   9/24/2021        2021c
# 3     Movie  **Confessions of an Invisible Girl**   9/22/2021         2021
# 4     Movie                           **Sankofa**   9/24/2021        1993S
# 5   TV Show     **The Great British Baking Show**   9/24/2021        2021s
# 6   Unknown                      **The Starling**   9/24/2021        2021)
# 7     Movie   **Motu Patlu in the Game of Zones**  05/01/2021        2019C
# 8     Movie                      **Je Suis Karl**   9/23/2021        2021S
# 9     Movie          **Motu Patlu in Wonderland**  05/01/2021         2013
# 10    Movie    **Motu Patlu: Deep Sea Adventure**  05/01/2021        2014s
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          4001 non-null   object
#  1   title         4001 non-null   object
#  2   date_added    4001 non-null   object
#  3   release_year  4001 non-null   object
#  4   rating        4001 non-null   object
#  5   listed_in     4001 non-null   object
# dtypes: object(6)
# memory usage: 187.7+ KB

# %%
netflix['title']

netflix['title']=netflix['title'].str.replace("\**" , "")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9940\166281219.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   netflix['title']=netflix['title'].str.replace("\**" , "")

# %%
netflix['title'].str.strip("**")
# Out:
# 0                   Dick Johnson Is Dead
# 1                              Ganglands
# 2                          Midnight Mass
# 3       Confessions of an Invisible Girl
# 4                                Sankofa
#                       ...
# 3996                          One 2 Ka 4
# 3997       Jim Norton: Mouthful of Shame
# 3998                          100 Meters
# 3999                       Burning Sands
# 4000               The Butterfly's Dream
# Name: title, Length: 4001, dtype: object

# %%
netflix.columns
# Out:
# Index(['type', 'title', 'date_added', 'release_year', 'rating', 'listed_in'], dtype='object')

# %%
netflix['date_added']=netflix['date_added'].str.replace('/', '-')

# %%
netflix
# Out:
#          type                             title  date_added release_year  \
# 0       Movie              Dick Johnson Is Dead   9-25-2021        2020)
# 1     TV Show                         Ganglands   9-24-2021        2021C
# 2     TV Show                     Midnight Mass   9-24-2021        2021c
# 3       Movie  Confessions of an Invisible Girl   9-22-2021         2021
# 4       Movie                           Sankofa   9-24-2021        1993S
# ...       ...                               ...         ...          ...
# 3996    Movie                        One 2 Ka 4   3-15-2017        2001S
# 3997    Movie     Jim Norton: Mouthful of Shame   3-14-2017         2017
# 3998    Movie                        100 Meters  03-10-2017        2016s
# 3999    Movie                     Burning Sands  03-10-2017        2017s
# 4000    Movie             The Butterfly's Dream  03-10-2017         2013
#
#        rating                                          listed_in
# ...

# %%
netflix['release_year']
# Out:
# 0       2020)
# 1       2021C
# 2       2021c
# 3        2021
# 4       1993S
#         ...
# 3996    2001S
# 3997     2017
# 3998    2016s
# 3999    2017s
# 4000     2013
# Name: release_year, Length: 4001, dtype: object

# %%
bad_char=['(',')', 'c', 'C', '.', '' , 's', 'S']

for i in bad_char:
    netflix['release_year'] = netflix['release_year'].str.replace(i,'')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9940\1562339645.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   netflix['release_year'] = netflix['release_year'].str.replace(i,'')

# %%
netflix['rating']
# Out:
# 0       ,?PG-13
# 1       ,?TV-MA
# 2       ,?TV-MA
# 3       ,?TV-PG
# 4       ,?TV-MA
#          ...
# 3996    ,?TV-14
# 3997    ,?TV-MA
# 3998    ,?TV-MA
# 3999    ,?TV-MA
# 4000    ,?TV-PG
# Name: rating, Length: 4001, dtype: object

# %%
netflix['rating']=netflix['rating'].str.strip(',?')

# %%
netflix['listed_in'].str.split(',', expand=True)
# Out:
#                              0                        1  \
# 0                Documentaries                     None
# 1               Crime TV Shows   International TV Shows
# 2                    TV Dramas                TV Horror
# 3     Children & Family Movies                 Comedies
# 4                       Dramas       Independent Movies
# ...                        ...                      ...
# 3996        Action & Adventure                 Comedies
# 3997           Stand-Up Comedy                     None
# 3998                    Dramas     International Movies
# 3999                    Dramas       Independent Movies
# 4000                    Dramas     International Movies
#
#                            2
# 0                       None
# 1      TV Action & Adventure
# 2               TV Mysteries
# 3                       None
# 4       International Movies
# ...                      ...
# 3996                  Dramas
# 3997                    None
# ...

# %%
netflix['listed_in'].str.split(',', expand=True)
# Out:
#                              0                        1  \
# 0                Documentaries                     None
# 1               Crime TV Shows   International TV Shows
# 2                    TV Dramas                TV Horror
# 3     Children & Family Movies                 Comedies
# 4                       Dramas       Independent Movies
# ...                        ...                      ...
# 3996        Action & Adventure                 Comedies
# 3997           Stand-Up Comedy                     None
# 3998                    Dramas     International Movies
# 3999                    Dramas       Independent Movies
# 4000                    Dramas     International Movies
#
#                            2
# 0                       None
# 1      TV Action & Adventure
# 2               TV Mysteries
# 3                       None
# 4       International Movies
# ...                      ...
# 3996                  Dramas
# 3997                    None
# ...

# %%
netflix['listed_in'] = netflix['listed_in'].str.split(',', expand=True)[0]

# %%
netflix
# Out:
#          type                             title  date_added release_year  \
# 0       Movie              Dick Johnson Is Dead   9-25-2021         2020
# 1     TV Show                         Ganglands   9-24-2021         2021
# 2     TV Show                     Midnight Mass   9-24-2021         2021
# 3       Movie  Confessions of an Invisible Girl   9-22-2021         2021
# 4       Movie                           Sankofa   9-24-2021         1993
# ...       ...                               ...         ...          ...
# 3996    Movie                        One 2 Ka 4   3-15-2017         2001
# 3997    Movie     Jim Norton: Mouthful of Shame   3-14-2017         2017
# 3998    Movie                        100 Meters  03-10-2017         2016
# 3999    Movie                     Burning Sands  03-10-2017         2017
# 4000    Movie             The Butterfly's Dream  03-10-2017         2013
#
#      rating                 listed_in
# 0     PG-13             Documentaries
# ...

# %% [markdown]
# # Insights

# %%
netflix['type'].value_counts() ## movies as most prominent
# Out:
# Movie      3453
# TV Show     481
# Unknown      67
# Name: type, dtype: int64

# %%
netflix['release_year'].value_counts()
# Out:
# 2019    613
# 2018    600
# 2020    581
# 2017    446
# 2021    385
#        ...
# 1972      1
# 1959      1
# 1925      1
# 1961      1
# 1969      1
# Name: release_year, Length: 63, dtype: int64

# %%
netflix['rating']
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-PG
# 4       TV-MA
#         ...
# 3996    TV-14
# 3997    TV-MA
# 3998    TV-MA
# 3999    TV-MA
# 4000    TV-PG
# Name: rating, Length: 4001, dtype: object

# %%
netflix['listed_in']
# Out:
# 0                  Documentaries
# 1                 Crime TV Shows
# 2                      TV Dramas
# 3       Children & Family Movies
# 4                         Dramas
#                   ...
# 3996          Action & Adventure
# 3997             Stand-Up Comedy
# 3998                      Dramas
# 3999                      Dramas
# 4000                      Dramas
# Name: listed_in, Length: 4001, dtype: object

# %%
netflix['rating'].value_counts()
# Out:
# TV-MA    1561
# TV-14    1041
# R         369
# TV-PG     340
# PG-13     226
# PG        124
# TV-Y7     120
# TV-Y      117
# TV-G       89
# G          13
# NC-17       1
# Name: rating, dtype: int64
